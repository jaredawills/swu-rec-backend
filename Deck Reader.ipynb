# %%
from bs4 import BeautifulSoup
import requests
from json import loads
import csv
import os
import pandas as pd
import numpy as np

# %%
'''
download_deck(num)

Description: Using BeautifulSoup and requests, download and Parse
             decklists that have been uploaded to sw-unlimited-db.com

Param:
    num: int
        The number of the decklist on sw-unlimited-db.com
'''

def download_deck(num):

# %%
num = 
## download_deck(num)

# %%
for i in range(770, 2000):
    if requests.get(f'https://sw-unlimited-db.com/decks/100').text != '':
        print(i, 'found')
        break
    else:
        print(i, end='\r')
# Out:
# 769
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11092\3084070812.py in <cell line: 1>()
#       1 for i in range(2000):
# ----> 2     if requests.get(f'https://sw-unlimited-db.com/decks/100').text != '':
#       3         print(i, 'found')
#       4         break
#       5     else:
#
# ~\anaconda3\envs\USML\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\envs\USML\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ...

# %%
requests.get(f'https://sw-unlimited-db.com/decks/10916').text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n    <base href="/"/>\n    <meta charset="UTF-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n    <link rel="stylesheet" href="/styles/style.css?v=BCgeLy9ECLXGgqEPtf2rQRkIa2chHXIkgQ986Sh0yt0">\n    <link rel="stylesheet" href="/css/output.css?v=lSBDmJ5x72SN8KZruLKVW_M9y5Z32CSf7xS7R-E8BgM" />\n    <title>Sabine full Aggro | SW-Unlimited-DB</title>\r\n\n\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">\n    <link rel="manifest" href="/site.webmanifest">\n    <link rel="mask-icon" color="#5bbad5" href="/safari-pinned-tab.svg">\n    <meta name="msapplication-TileColor" content="#da532c">\n    <meta name="theme-color" content="#ffffff">\n\n    <style>\n        :root {\n            --main-color: #000000;\n            --main-col
# ...

# %%
requests.get(f'https://sw-unlimited-db.com/decks/100').text
# Out:
# ''
